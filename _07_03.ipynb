# %%
toplam=0
while True:
    sayi=float(input("sayi giriniz: "))
    if sayi==-1:
        break
    else:
        toplam+=sayi
        print(f"Girilen sayinin toplami:{toplam}")
# Out:
# Girilen sayinin toplami:5.0
# Girilen sayinin toplami:11.0
# Girilen sayinin toplami:22.0
