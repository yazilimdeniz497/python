# %%
a=3
b=10
print("a/b  = ",a/b)
print("a//b = ",a//b)
print("a+b  = ",a+b)
# Out:
# a/b  =  0.3
# a//b =  0
# a+b  =  13

# %%
x = 7
y = 5
print("x>y",x>y) 
print("x<y",x<y)
print("x=y",x==y)
print("x>=y",x>=y)
print("x<=y",x<=y)
# Out:
# x>y True
# x<y False
# x=y False
# x>=y True
# x<=y False

# %%
yas=20
mezuniyet="lise"
print(yas>=18 and mezuniyet=="lise")
# Out:
# True

# %%
sayi1=10
sayi1=sayi1+2
sayi2=sayi1
sayi2+=2
print(sayi1==sayi2)
# Out:
# False

# %%
isim=input("isminizi Giriniz: ")
print("merhaba",isim)
# Out:
# merhaba ahmet

# %%
print(type(isim))
# Out:
# <class 'str'>

# %%
sayi=input("sayiyi giriniz: ")
print(sayi+10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 sayi=input("sayiyi giriniz: ")
# ----> 2 print(sayi+10)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(sayi+str(10))
# Out:
# 1010

# %%
sayi1=int(input("1.sayiyi giriniz: "))
print(sayi)
# Out:
# 10

# %%
print("Ocak","Şubat","Mart",end="...")
print(sayi,sayi1,sayi2)
# Out:
# Ocak Şubat Mart...10 50 14

# %%
urun="kalem"
fiyat=15.5
print("Urun: "+urun+" Fiyat: ",fiyat)
# Out:
# Urun: kalem Fiyat:  15.5

# %%
urun="ekmek"
fiyat=15
print("urun: {} fiyat:{}".format(urun,fiyat))
# Out:
# urun: ekmek fiyat:15

# %%
print(f"Ürün {urun} Fiyat {fiyat}")
# Out:
# Ürün ekmek Fiyat 15
