# %%
toplam=0
print("Pozitif sayilar giriniz (Bitirmek için 0 girin)")
while True:
     girilen_sayi=int(input("Lütfen pozitif sayı giriniz: "))
     if girilen_sayi==0:
         break
     elif girilen_sayi>0:
         toplam+=girilen_sayi
     else:
         print(f"negatif sayı yok sayıldı")
     print(f"girilen sayilarin toplami: {toplam}")
# Out:
# Pozitif sayilar giriniz (Bitirmek için 0 girin)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       4      girilen_sayi=int(input("Lütfen pozitif sayı giriniz: "))
#       5      if girilen_sayi==0:
#       6          break
#       7      elif girilen_sayi>0:
# ----> 8          toplam+=sayi
#       9      else:
#      10          print(f"negatif sayı yok sayıldı")
#      11      print(f"girilen sayilarin toplami: {toplam}")
#
# NameError: name 'sayi' is not defined
