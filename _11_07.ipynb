# %%
sayilar=[10,15,30,7]
ucevebesebolunebilen=[]
for sayi in sayilar:


    if sayi%3==0:
       ucevebesebolunebilen.append(sayi)
       
    elif sayi%5==0:
       ucevebesebolunebilen.append(sayi)

print(ucevebesebolunebilen)
# Out:
# [10, 15, 30]
