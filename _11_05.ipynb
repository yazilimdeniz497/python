# %%
input_one=input("1.sayi listesini Giriniz: ")
input_one=[int(num) for num in input_one.split()]
input_two=input("2.sayi listesini Giriniz: ")
input_one=[int(num) for num in input_two.split()]
marged_list=input_one+input_two
print("1.liste: ",input_one)
print("2.liste",input_two)
print("2 listenin birleşimi: ",marged_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 input_one=input("1.sayi listesini Giriniz: ")
#       2 input_one=[int(num) for num in input_one.split()]
#       3 input_two=input("2.sayi listesini Giriniz: ")
# ----> 4 marged_list=input_one+input_two
#       5 print("1.liste: ",input_one)
#       6 print("2.liste",input_two)
#       7 print("2 listenin birleşimi: ",marged_list)
#
# TypeError: can only concatenate list (not "str") to list
