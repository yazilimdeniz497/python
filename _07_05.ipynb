# %%
toplam = 0
for sayi in range(1,101):
    toplam+=sayi

print(f"1den 100 e kadar olan sayilarin toplami:{toplam}")
# Out:
# 1den 100 e kadar olan sayilarin toplami:5050

# %%
n=int(input("Limit değeri Giriniz: "))
toplam=0
for sayi in range(1,n):
    toplam+=sayi
print(f"1 den {n} e kadar olan sayıların toplamı {toplam}")
# Out:
# 1 den 10 e kadar olan sayıların toplamı 45
