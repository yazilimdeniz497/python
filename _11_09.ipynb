# %%
grades_matrix=[[80,70],[90,40],[90,70]]
averages=[]
print(grades_matrix[0])
# Out:
# [80, 70]

# %%
for grades in grades_matrix:
    average=sum(grades)/len(grades)
    averages.append(average)   
print(averages)
# Out:
# [75.0, 65.0, 80.0]
