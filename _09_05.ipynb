# %%
sayilar=[12,5,7,9,27,14]

# %%
buyuk=sayilar[0]
for sayi in sayilar:
    if sayi>buyuk:
        buyuk=sayi
print(f"en buyuk sayi: {buyuk}")
# Out:
# en buyuk sayi: 27

# %%
min(sayilar)
# Out:
# 5

# %%
max(sayilar)
# Out:
# 27
