# %%
sayilar=[4,7,9,11]
asalsayilar=[]
for sayi in sayilar:
  asalsayi=True
  for i in range(2,sayi):
     if sayi%i==0:
       asalsayi=False
     elif asalsayi:
       asalsayilar.append(sayi)
     
    



print(asalsayilar)
# Out:
# 11
