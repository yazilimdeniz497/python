# %%
matris=[[1,2,3], [4,5,6]]

# %%
matris
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
matris[0][2]
# Out:
# 3

# %%
matris[0]
# Out:
# [1, 2, 3]

# %%
print(type(matris))
# Out:
# <class 'list'>

# %%
print(type(matris[0][2]))
# Out:
# <class 'int'>

# %%
matris=[]
matris.append([1,2,3])
matris.append([4,5,6])

# %%
matris
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
numbers=list(range(1,7))
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
matris=[[0,1,2],[0,1,2]]

# %%
for i in range(3):
    for j in range(2):
        matris[i][j]=numbers[p]
        p+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 for i in range(3):
#       2     for j in range(2):
# ----> 3         matris[i][j]=numbers[p]
#       4         p+=1
#
# NameError: name 'p' is not defined

# %%
for i in range(2):
    for j in range(3):
        print(f"{matris[i][j]:4d}",end=" ")
    print(" ")
# Out:
#    1    2    3
#    4    5    6

# %%
print(len(matris))
# Out:
# 2

# %%
matris
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
matris[0]
# Out:
# [1, 2, 3]
