# %%
def greet():
    print("Merhaba Hoş geldiniz")

# %%
greet()
# Out:
# Merhaba Hoş geldiniz

# %%
def greet(name):
    print(f"Merhaba {name.strip()} hosgeldiniz")

# %%
greet("ayse")
# Out:
# Merhaba ayse hosgeldiniz

# %%
names=["ali","leyla","can","merve"]
