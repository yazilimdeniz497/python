# %%
toplam=0
while True:
    print(f"Girilen sayinin toplami:{toplam}")

# %%
n="merhaba"
for i in range(1,10):
    print(n)
# Out:
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
