# %%
i=1
while i<5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
n=int(input("Limit dediğiniz değer: "))
i=1
while i<=n:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
ifade="Btk Akademi"
for karakter in ifade:
    print(karakter.upper())
# Out:
# B
# T
# K
#
# A
# K
# A
# D
# E
# M
# I

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
n=int(input("limit değeri: "))
for i in range(1,n+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
