# %%
x=int(input("x:"))
if x>5:
    print(f"{x}>5")
print("program bitti.")
# Out:
# program bitti.

# %%
if sayi%2==0:
    print(f"{sayi} çifttir" )

# %%
sayi=float(input("bir sayi giriniz: "))
if sayi%2==0:
    print(f"{sayi} sayi çiftir")
else:
    print(f"{sayi} sayi tektir")
# Out:
# 15.0 sayi tektir

# %%
sayi1=float(input("sayi giriniz: "))
if sayi1>0:
    print(f"sayi {sayi1} pozitif")
elif sayi1<10:
    print(f"sayi {sayi1} negatif")
else:
    print("sayi 0'dir")
# Out:
# sayi 20.0 pozitif

# %%
dogru_kullaniciadi="admin"
dogru_sifre="1234"
kullanici=input("kullanici adi giriniz: ")
sifre=input("sifre giriniz: ")
if kullanici==dogru_kullaniciadi:
    if sifre==dogru_sifre:
        print("kullanici girisi dogrulandi")
    else:
        print("kullanici girisi yanlis")
else:
    print("böyle bir kullanıcı adı bulunamadı")
# Out:
# böyle bir kullanıcı adı bulunamadı
