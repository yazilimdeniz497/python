# %%
name=input("Adinizi Giriniz: ")
print(name.lower())
# Out:
# ali̇

# %%
word1="Merhaba"
word2=word1
print(word1,word2)
word1="Hoşçakal"
print(word1,word2)
# Out:
# Merhaba Merhaba
# Hoşçakal Merhaba

# %%
name="Omer"
print(name[-1])
print(name[0])
print(name[-2])
# Out:
# r
# O
# e

# %%
print(len(name))
# Out:
# 4

# %%
sentence="python ogreniyorum"
print(sentence[:6])
# Out:
# python
