# %%
isimler=["ahmet","can","merve","filiz"]
for isim in isimler:
    print(isim)
# Out:
# ahmet
# can
# merve
# filiz

# %%
for i in range(len(isimler)):
    print(f"{i}. eleman {isimler[i]}")
# Out:
# 0. eleman ahmet
# 1. eleman can
# 2. eleman merve
# 3. eleman filiz

# %%
for i in range(len(isimler)-1,-1,-1):
    print(f"{i}.elemanlardaki {isimler[i]}")
# Out:
# 3.elemanlardaki filiz
# 2.elemanlardaki merve
# 1.elemanlardaki can
# 0.elemanlardaki ahmet

# %%
# Out:
# 0. indisteki eleman ahmet
# 1. indisteki eleman can
# 2. indisteki eleman merve
# 3. indisteki eleman filiz

# %%
i=0
while i<len(isimler):
     i=i+1
     print(f"{i}. indisteki eleman {isimler[i]}")
# Out:
# 1. indisteki eleman can
# 2. indisteki eleman merve
# 3. indisteki eleman filiz
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 i=0
#       2 while i<len(isimler):
#       3      i=i+1
# ----> 4      print(f"{i}. indisteki eleman {isimler[i]}")
#       5
#
# IndexError: list index out of range
