# %%
sayi=10
pi=3.14
kontrol=True
isim="Mehmet"
print(pi)
print(sayi)
print(kontrol)
print(isim)
# Out:
# 3.14
# 10
# True
# Mehmet

# %%
print(type(pi))
print(type(sayi))
# Out:
# <class 'float'>
# <class 'int'>

# %%
print(type(isim))
print(type(kontrol))
