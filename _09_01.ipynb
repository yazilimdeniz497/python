# %%
sayilar=[5,7,8,10,12]

# %%
sayilar
# Out:
# [5, 7, 8, 10, 12]

# %%
print(sayilar[0])
print(sayilar[3])
# Out:
# 5
# 10

# %%
isimler=["ahmet","can","merve","filiz"]

# %%
print(isimler[-1])
print(isimler[-2])
# Out:
# filiz
# merve

# %%
karisik=[5,"Ahmet",True,3.14,False]
print(karisik)
# Out:
# [5, 'Ahmet', True, 3.14, False]

# %%
sayilar
# Out:
# [5, 7, 8, 10, 12]

# %%
sayilar.append(-5)

# %%
sayilar
# Out:
# [5, 7, 8, 10, 12, -5]

# %%
sayilar.insert(2,7)

# %%
print(sayilar)
# Out:
# [5, 7, 7, 8, 10, 12, -5]

# %%
sayilar.pop(2)
# Out:
# 7

# %%
print(sayilar)
# Out:
# [5, 7, 8, 10, 12, -5]

# %%
sayilar.sort()

# %%
print(sayilar)
# Out:
# [-5, 5, 7, 8, 10, 12]

# %%
sayilar.reverse()

# %%
print(sayilar)
# Out:
# [12, 10, 8, 7, 5, -5]

# %%
len(sayilar)
# Out:
# 6

# %%
print(sorted(sayilar))
# Out:
# [-5, 5, 7, 8, 10, 12]

# %%
sorted(sayilar)
print(sayilar)
# Out:
# [12, 10, 8, 7, 5, -5]

# %%
sayilar.remove(5)
print(sayilar)
# Out:
# [12, 10, 8, 7]

# %%
for sayi in sayilar:
    print(sayi)
# Out:
# 12
# 10
# 8
# 7
