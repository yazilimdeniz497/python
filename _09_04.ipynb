# %%
sayilar=[]
for i in range(5):
    s=int(input("sayi giriniz: "))
    sayilar.append(s)
    toplam=0
    for sayi in sayilar:
        toplam+=sayi
        ortalama=toplam/len(sayilar)
print(ortalama)
# Out:
# 5.0
