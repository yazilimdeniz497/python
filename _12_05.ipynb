# %%
title="Yapay zekanin Gelecegi"
word=title.split()
print(word)
# Out:
# ['Yapay', 'zekanin', 'Gelecegi']

# %%
for word in words:
    new_words=" "
    new_words=word.lower()
print(new_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for word in words:
#       2     new_words=" "
#       3     new_words=word.lower()
#       4     print(new_words)
#
# NameError: name 'words' is not defined
